# %% [markdown]
# <a href="https://colab.research.google.com/github/Likhithagoud3/NUMPY_FUNDAMENTALS/blob/main/pandas_practice_basic_commands_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Salaries.csv')

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (78, 6)

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]>

# %%
df['salary']
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df['salary'].mean()
# Out:
# 108023.78205128205

# %%
df['salary'].median()
# Out:
# 104671.0

# %%
df['salary'].mode()
# Out:
# 0    92000
# Name: salary, dtype: int64

# %%
df['salary'].var()
# Out:
# 800531254.0427904

# %%
df['salary'].std()
# Out:
# 28293.661022264165

# %%
df['salary'].skew()
# Out:
# 0.45210256755588096

# %%
df[['salary','phd']].mean()
# Out:
# salary    108023.782051
# phd           19.705128
# dtype: float64

# %%
df[['salary','phd']].median()
# Out:
# salary    104671.0
# phd           18.5
# dtype: float64

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df['salary']
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df['salary'].mean()
# Out:
# 108023.78205128205

# %%
df['salary'].median()
# Out:
# 104671.0

# %%
df['salary'].mode()
# Out:
# 0    92000
# Name: salary, dtype: int64

# %%
df['salary'].var()
# Out:
# 800531254.0427904

# %%
df['salary'].std()
# Out:
# 28293.661022264165

# %%
df['salary'].skew()
# Out:
# 0.45210256755588096

# %%
df[['salary','phd']].mean()
# Out:
# salary    108023.782051
# phd           19.705128
# dtype: float64

# %%
df[['salary','phd']].median()
# Out:
# salary    104671.0
# phd           18.5
# dtype: float64

# %%
df.mean(numeric_only=True)
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# phd            18.5
# service        14.5
# salary     104671.0
# dtype: float64

# %%
# prompt: filter the record where the salary is greater than 500000 in df

df_filtered = df[df['salary'] > 500000]
df_filtered
# Out:
# Empty DataFrame
# Columns: [rank, discipline, phd, service, sex, salary]
# Index: []

# %%
df[df['salary'] >50000]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.iloc[:,:]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.iloc[0:10,0:3]
# Out:
#         rank discipline  phd
# 0       Prof          B   56
# 1       Prof          A   12
# 2       Prof          A   23
# 3       Prof          A   40
# 4       Prof          B   20
# 5       Prof          A   20
# 6  AssocProf          A   20
# 7       Prof          A   18
# 8       Prof          A   29
# 9       Prof          A   51

# %%
df.iloc[0:10,1:5]
# Out:
#   discipline  phd  service   sex
# 0          B   56       49  Male
# 1          A   12        6  Male
# 2          A   23       20  Male
# 3          A   40       31  Male
# 4          B   20       18  Male
# 5          A   20       20  Male
# 6          A   20       17  Male
# 7          A   18       18  Male
# 8          A   29       19  Male
# 9          A   51       51  Male

# %%
df.iloc[0:10,[1,3,5]]
# Out:
#   discipline  service  salary
# 0          B       49  186960
# 1          A        6   93000
# 2          A       20  110515
# 3          A       31  131205
# 4          B       18  104800
# 5          A       20  122400
# 6          A       17   81285
# 7          A       18  126300
# 8          A       19   94350
# 9          A       51   57800

# %%
# prompt: i want to select 10 rows and columns  1,3,5

df.iloc[0:10, [1, 3, 5]]
# Out:
#   discipline  service  salary
# 0          B       49  186960
# 1          A        6   93000
# 2          A       20  110515
# 3          A       31  131205
# 4          B       18  104800
# 5          A       20  122400
# 6          A       17   81285
# 7          A       18  126300
# 8          A       19   94350
# 9          A       51   57800

# %%
df.loc[0,'salary']
# Out:
# 186960

# %%
df.loc[5,'salary']
# Out:
# 122400

# %%
df['rank'].value_counts()
# Out:
# rank
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: count, dtype: int64

# %%
df['rank'].max()
# Out:
# 'Prof'

# %%
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df.groupby('rank').mean(numeric_only=True)
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df['salary'].mode()
# Out:
# 0    92000
# Name: salary, dtype: int64

# %%
df['sex'].mode()
# Out:
# 0    Female
# 1      Male
# Name: sex, dtype: object

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      39
# Female    39
# Name: count, dtype: int64

# %%
df.groupby('rank').mean(numeric_only=True)
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.groupby('rank')[['salary','phd']].mean()
# Out:
#                   salary        phd
# rank
# AssocProf   91786.230769  15.076923
# AsstProf    81362.789474   5.052632
# Prof       123624.804348  27.065217

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('/Universities.csv')

# %%
#plot histogram on SAT column

plt.hist(df['SAT'])
plt.xlabel('SAT')
plt.ylabel('count')
plt.title('Histogram of SAT')
plt.show()

# %%
sns.histplot(df['Accept'])
plt.xlabel('Accept1')
plt.ylabel('Frequency')
plt.show()

# %%
# prompt: can you create a histogram on df on sat column can you change the color pink,given the edgecolor to black,can you use seaborn library

import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame and 'SAT' is the column you want to plot
sns.histplot(df['SAT'], color='pink', edgecolor='black')
plt.xlabel('SAT')
plt.ylabel('Frequency')
plt.title('Histogram of SAT')
plt.show()

# %%
 plt.plot(df['SAT'], df['Accept'],'rs')
 plt.title('SAT vs Accept')
 plt.xlabel('SAT')
 plt.ylabel('Accept')
 plt.xlabel('SAT')
 plt.ylabel('Accept')
 plt.title('Scatter Plot of SAT vs Accept')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of SAT vs Accept')

# %%
# prompt: create  a scatter plot between Top 10 column and accept column and use blue color circle markers in the scatter plot

plt.scatter(df['Top10'], df['Accept'], color='blue', marker='o')
plt.xlabel('Top10')
plt.ylabel('Accept')
plt.title('Scatter Plot of Top10 vs Accept')
plt.show()

# %%
sns.pairplot(df.iloc[:,1:])

# %%
sns.pairplot(df.iloc[:,1:3])

# %%
# prompt: create a pairplot on my dataframe df , i want only for my SAT  column 1 and column2

sns.pairplot(df[['SAT', 'Accept']])
plt.show()

# %%
# prompt: Can a pairplot on my dataframe df, i want only for my SAT column and Top 10 column

sns.pairplot(df[['SAT', 'Top10']])
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(df['Accept'])
# Out:
# <Axes: xlabel='Accept', ylabel='Density'>

# %%
sns.distplot(df['SAT'])
# Out:
# <Axes: xlabel='SAT', ylabel='Density'>

# %%
plt.boxplot(df['Accept'], vert=False)
plt.xlabel('Accept')
plt.ylabel('Value')
plt.title('Boxplot of Accept')
plt.show()

# %%
# prompt: create a boxplot on SAT column in my dataframe df

plt.boxplot(df['SAT'])
plt.xlabel('SAT')
plt.title('Boxplot of SAT')
plt.show()
